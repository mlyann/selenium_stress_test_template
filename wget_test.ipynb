# %%
import time
import os
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
MeetingURL = "https://develop.blackstoneamoffice.com/editors/Reports/MeetingStatusReport.aspx?meetingid=2699"
NUM = 5
TIME_LINE = 10

# %%
def collect_load_times(MeetingURL, num):
    timestamps = []
    load_times = []
    
    for i in range(num):
        start = time.time()
        filename = f"MeetingStatusReport_{i}.aspx"
        os.system(f'wget {MeetingURL} -O {filename}')
        end = time.time()
        os.system(f"rm {filename}")
        delta = end - start

        print("--------------------Loading Time--------------------")
        print(delta)
        print("----------------------------------------------------")


        timestamps.append(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start)))
        load_times.append(delta)

        time.sleep(5)
    
    return timestamps, load_times

# %%
def calculate_statistics(load_times, loading_time_line):
    stats = {}
    stats['count_exceeding'] = np.sum(np.array(load_times) > loading_time_line)
    stats['mean'] = np.mean(load_times)
    stats['median'] = np.median(load_times)
    stats['max'] = np.max(load_times)
    stats['min'] = np.min(load_times)
    
    return stats

# %%
def plot_load_times(timestamps, load_times, stats):
    # Display statistics
    print(
        f"Counts of Exceeding Loading Time Line ({stats['mean']} seconds): {stats['count_exceeding']}\n"
        f"Mean of Loading Time: {stats['mean']}\n"
        f"Median of Loading Time: {stats['median']}\n"
        f"Max of Loading Time: {stats['max']}\n"
        f"Min of Loading Time: {stats['min']}\n"
    )

    # Plotting
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps, load_times, marker='o', linestyle='-')
    plt.xticks(rotation=45, ha='right')
    plt.xlabel('Timestamp')
    plt.ylabel('Loading Time (s)')
    plt.title('Webpage Loading Times Over Multiple Requests')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print(stats)

# %%
timestamps, load_times = collect_load_times(MeetingURL, NUM)
stats = calculate_statistics(load_times, TIME_LINE)
plot_load_times(timestamps, load_times, stats)
# Out:
# --2024-07-23 08:11:19--  https://develop.blackstoneamoffice.com/editors/Reports/MeetingStatusReport.aspx?meetingid=2699
# Resolving develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)... 35.175.164.203
# Connecting to develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)|35.175.164.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194768 (190K) [text/html]
# Saving to: ‘MeetingStatusReport_0.aspx’
#
#      0K .......... .......... .......... .......... .......... 26% 2.19M 0s
#     50K .......... .......... .......... .......... .......... 52% 4.96M 0s
#    100K .......... .......... .......... .......... .......... 78% 39.7M 0s
#    150K .......... .......... .......... ..........           100% 5.30M=0.04s
#
# 2024-07-23 08:11:22 (4.56 MB/s) - ‘MeetingStatusReport_0.aspx’ saved [194768/194768]
# ---------------Loading Time---------------
# 3.2798521518707275
# ------------------------------------------
# --2024-07-23 08:11:27--  https://develop.blackstoneamoffice.com/editors/Reports/MeetingStatusReport.aspx?meetingid=2699
# Resolving develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)... 35.175.164.203
# Connecting to develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)|35.175.164.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194768 (190K) [text/html]
# Saving to: ‘MeetingStatusReport_1.aspx’
#
#      0K .......... .......... .......... .......... .......... 26% 2.47M 0s
#     50K .......... .......... .......... .......... .......... 52% 5.04M 0s
#    100K .......... .......... .......... .......... .......... 78% 40.4M 0s
#    150K .......... .......... .......... ..........           100% 47.0M=0.03s
#
# 2024-07-23 08:11:31 (5.89 MB/s) - ‘MeetingStatusReport_1.aspx’ saved [194768/194768]
# ---------------Loading Time---------------
# 3.780327796936035
# ------------------------------------------
# --2024-07-23 08:11:36--  https://develop.blackstoneamoffice.com/editors/Reports/MeetingStatusReport.aspx?meetingid=2699
# Resolving develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)... 35.175.164.203
# Connecting to develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)|35.175.164.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194768 (190K) [text/html]
# Saving to: ‘MeetingStatusReport_2.aspx’
#
#      0K .......... .......... .......... .......... .......... 26% 2.05M 0s
#     50K .......... .......... .......... .......... .......... 52% 5.26M 0s
#    100K .......... .......... .......... .......... .......... 78% 26.0M 0s
#    150K .......... .......... .......... ..........           100%  148M=0.04s
#
# 2024-07-23 08:11:39 (5.27 MB/s) - ‘MeetingStatusReport_2.aspx’ saved [194768/194768]
# ---------------Loading Time---------------
# 3.5906388759613037
# ------------------------------------------
# --2024-07-23 08:11:45--  https://develop.blackstoneamoffice.com/editors/Reports/MeetingStatusReport.aspx?meetingid=2699
# Resolving develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)... 35.175.164.203
# Connecting to develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)|35.175.164.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194768 (190K) [text/html]
# Saving to: ‘MeetingStatusReport_3.aspx’
#
#      0K .......... .......... .......... .......... .......... 26% 2.78M 0s
#     50K .......... .......... .......... .......... .......... 52% 5.46M 0s
#    100K .......... .......... .......... .......... .......... 78% 36.3M 0s
#    150K .......... .......... .......... ..........           100% 47.6M=0.03s
#
# 2024-07-23 08:11:48 (6.48 MB/s) - ‘MeetingStatusReport_3.aspx’ saved [194768/194768]
# ---------------Loading Time---------------
# 3.5819809436798096
# ------------------------------------------
# --2024-07-23 08:11:53--  https://develop.blackstoneamoffice.com/editors/Reports/MeetingStatusReport.aspx?meetingid=2699
# Resolving develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)... 35.175.164.203
# Connecting to develop.blackstoneamoffice.com (develop.blackstoneamoffice.com)|35.175.164.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194768 (190K) [text/html]
# Saving to: ‘MeetingStatusReport_4.aspx’
#
#      0K .......... .......... .......... .......... .......... 26% 2.55M 0s
#     50K .......... .......... .......... .......... .......... 52% 5.69M 0s
#    100K .......... .......... .......... .......... .......... 78% 18.3M 0s
#    150K .......... .......... .......... ..........           100% 17.3M=0.03s
#
# 2024-07-23 08:11:57 (5.69 MB/s) - ‘MeetingStatusReport_4.aspx’ saved [194768/194768]
# ---------------Loading Time---------------
# 3.6427290439605713
# ------------------------------------------
# Counts of Exceeding Loading Time Line (3.5751057624816895 seconds): 0
# Mean of Loading Time: 3.5751057624816895
# Median of Loading Time: 3.5906388759613037
# Max of Loading Time: 3.780327796936035
# Min of Loading Time: 3.2798521518707275
# {'count_exceeding': 0, 'mean': 3.5751057624816895, 'median': 3.5906388759613037, 'max': 3.780327796936035, 'min': 3.2798521518707275}
